# %% [markdown]
# ## Data Experiment
# Using UEFA Champions League statistics from Kaggle
# [Download here](https://www.kaggle.com/sarangpurandare/uefa-champions-league-player-statistics)

# %%
import pandas as pd 
cl = pd.read_csv('uefa_cl.csv')
type(cl)
# Out:
# pandas.core.frame.DataFrame

# %%
len(cl)
# Out:
# 5733

# %%
cl.shape
# Out:
# (5733, 109)

# %%
cl.head()
# Out:
#    Unnamed: 0                name                       season season year  \
# 0           0    Robin van Persie       Champions League 13/14       13/14
# 1           1         Ashley Cole       Champions League 13/14       13/14
# 2           2  José Antonio Reyes  UEFA Champions League 15/16       15/16
# 3           3  Roman Weidenfeller       Champions League 13/14       13/14
# 4           4  Roman Weidenfeller       Champions League 14/15       14/15
#
#                 team  rating  goals  bigChancesCreated  bigChancesMissed  \
# 0  manchester-united     NaN      4                NaN               NaN
# 1            chelsea     NaN      0                NaN               NaN
# 2            sevilla    7.25      0                0.0               1.0
# 3  borussia-dortmund     NaN      0                NaN               NaN
# 4  borussia-dortmund     NaN      0                NaN               NaN
#
# ...

# %%
cl.tail()
# Out:
#       Unnamed: 0                    name                       season  \
# 5728        5728           Ilya Zabarnyi  UEFA Champions League 20/21
# 5729        5729         Kristian Kolcak       Champions League 13/14
# 5730        5730         Kristian Kolcak       Champions League 14/15
# 5731        5731         Bogdan V'Yunnik  UEFA Champions League 20/21
# 5732        5732  Sabua Leon Rustamovich  UEFA Champions League 20/21
#
#      season year               team    rating  goals  bigChancesCreated  \
# 5728       20/21        dynamo-kyiv  6.533333      0                0.0
# 5729       13/14  slovan-bratislava       NaN      0                NaN
# 5730       14/15  slovan-bratislava       NaN      0                NaN
# 5731       20/21   shakhtar-donetsk  0.000000      0                0.0
# 5732       20/21       fc-krasnodar  6.400000      0                0.0
#
#       bigChancesMissed  assists  ...  scoringFrequency  yellowRedCards  \
# ...

# %%
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5733 entries, 0 to 5732
# Columns: 109 entries, Unnamed: 0 to substitutionsOut
# dtypes: float64(101), int64(4), object(4)
# memory usage: 4.8+ MB

# %%
cl.describe()
# Out:
#         Unnamed: 0       rating        goals  bigChancesCreated  \
# count  5733.000000  4069.000000  5733.000000        4069.000000
# mean   2866.000000     6.724582     0.504622           0.515606
# std    1655.118878     0.896538     1.207323           1.079470
# min       0.000000     0.000000     0.000000           0.000000
# 25%    1433.000000     6.575000     0.000000           0.000000
# 50%    2866.000000     6.800000     0.000000           0.000000
# 75%    4299.000000     7.033333     1.000000           1.000000
# max    5732.000000     9.700000    17.000000          11.000000
#
#        bigChancesMissed      assists  goalsAssistsSum  accuratePasses  \
# count       4069.000000  5635.000000      5635.000000     4069.000000
# mean           0.402310     0.321739         0.810470      135.311870
# std            1.030319     0.743411         1.652205      133.109941
# min            0.000000     0.000000         0.000000        0.000000
# ...

# %%
names = cl['name']

# %%
names.value_counts()
# Out:
# Marcelo                   12
# Fernando                  11
# Danilo                     9
# Alexis Sánchez             8
# Gerard Piqué               8
#                           ..
# Joel Pedro                 1
# Kevin Malget               1
# Pape Souaré                1
# Yuri Berchiche             1
# Sabua Leon Rustamovich     1
# Name: name, Length: 2836, dtype: int64

# %%
cl['team'].value_counts()
# Out:
# juventus             194
# borussia-dortmund    193
# atletico-madrid      179
# barcelona            163
# manchester-city      162
#                     ...
# athletic-bilbao        4
# milan                  4
# austria-wien           3
# fcsb                   3
# real-sociedad          2
# Name: team, Length: 93, dtype: int64

# %%
cl.loc[cl['team'] == 'slovan-bratislava', 'name'].value_counts()
# Out:
# Kristian Kolcak     2
# Nicolás Gorosito    2
# Juraj Halenar       2
# Igor Žofčák         2
# Seydouba Soumah     2
# Marko Milinkovic    2
# Erik Grendel        2
# Karol Mészáros      2
# Matej Jakubek       2
# Pavel Fořt          2
# Lester Peltier      2
# Jiri Kladrubsky     1
# Dávid Hudák         1
# Branislav Niňaj     1
# Róbert Vittek       1
# Richard Lásik       1
# Miloš Josimov       1
# Erik Cikos          1
# Filip Hlohovský     1
# Matúš Putnocký      1
# Dušan Perniš        1
# Mamadou Bagayoko    1
# Tomas Jablonsky     1
# Samuel Štefánik     1
# Name: name, dtype: int64

# %%
cl.loc[cl['goals'] > 5, 'name']
# Out:
# 72              Cristiano Ronaldo
# 73              Cristiano Ronaldo
# 74              Cristiano Ronaldo
# 75              Cristiano Ronaldo
# 76              Cristiano Ronaldo
# 77              Cristiano Ronaldo
# 175            Zlatan Ibrahimović
# 254                 Karim Benzema
# 613                  Carlos Tévez
# 696                  Lionel Messi
# 697                  Lionel Messi
# 698                  Lionel Messi
# 699                  Lionel Messi
# 700                  Lionel Messi
# 701                  Lionel Messi
# 853                    Edin Džeko
# 862                   Gareth Bale
# 965                   Luis Suárez
# 966                   Luis Suárez
# 979                 Sergio Agüero
# 980                 Sergio Agüero
# 984                 Sergio Agüero
# 1142                 Artem Dzyuba
# 1187                  Diego Costa
# 1205               Edinson Cavani
# 1207               Edinson Cavani
# 1208               Edinson Cavani
# ...

# %%
cl[(cl['goals'] > 5) & (cl['assists'] > 2)]
# Out:
#       Unnamed: 0                name                       season season year  \
# 73            73   Cristiano Ronaldo       Champions League 14/15       14/15
# 74            74   Cristiano Ronaldo  UEFA Champions League 15/16       15/16
# 75            75   Cristiano Ronaldo  UEFA Champions League 16/17       16/17
# 76            76   Cristiano Ronaldo  UEFA Champions League 17/18       17/18
# 697          697        Lionel Messi       Champions League 14/15       14/15
# 701          701        Lionel Messi  UEFA Champions League 18/19       18/19
# 965          965         Luis Suárez       Champions League 14/15       14/15
# 966          966         Luis Suárez  UEFA Champions League 15/16       15/16
# 1743        1743       Thomas Müller       Champions League 14/15       14/15
# 1879        1879         Dušan Tadić  UEFA Champions League 18/19       18/19
# 1900        1900      Yacine Brahimi       Champions League 14/15       14/15
# ...

# %%
juv = cl.loc[(cl['team'] == 'juventus'), ['name','goals']]
juv
# Out:
#                    name  goals
# 72    Cristiano Ronaldo     17
# 73    Cristiano Ronaldo     10
# 74    Cristiano Ronaldo     16
# 75    Cristiano Ronaldo     12
# 76    Cristiano Ronaldo     15
# ...                 ...    ...
# 5485    Simone Muratore      0
# 5546  Gianluca Frabotta      0
# 5584    Weston McKennie      1
# 5585    Weston McKennie      0
# 5660   Dejan Kulusevski      0
#
# [194 rows x 2 columns]

# %%
juv.groupby(['name']).sum()
# Out:
#                        goals
# name
# Aaron Ramsey               6
# Adrien Rabiot              4
# Alessandro Matri           0
# Alex Sandro                0
# Andrea Barzagli            0
# Andrea Pirlo               1
# Angelo Ogbonna             0
# Arthur                     0
# Blaise Matuidi             6
# Carlos Tévez               7
# Claudio Marchisio          1
# Cristiano Ronaldo         80
# Danilo                     1
# Dejan Kulusevski           0
# Fabio Quagliarella         2
# Fabrizio Caligara          0
# Federico Bernardeschi      2
# Federico Chiesa            0
# Federico Peluso            0
# Gianluca Frabotta          0
# Gianluigi Buffon           0
# Giorgio Chiellini          1
# Gonzalo Higuaín           17
# Hernanes                   0
# Juan Cuadrado              4
# Leonardo Bonucci           1
# Leonardo Spinazzola        0
# Marco Olivieri             0
# Mario Mandžukić           18
# Marko Pjaca                1
# Martín Cáceres             0
# ...

# %%
cl.loc[(cl['team'] == 'juventus'), ['name','goals']].groupby(['name']).sum()
# Out:
#                        goals
# name
# Aaron Ramsey               6
# Adrien Rabiot              4
# Alessandro Matri           0
# Alex Sandro                0
# Andrea Barzagli            0
# Andrea Pirlo               1
# Angelo Ogbonna             0
# Arthur                     0
# Blaise Matuidi             6
# Carlos Tévez               7
# Claudio Marchisio          1
# Cristiano Ronaldo         80
# Danilo                     1
# Dejan Kulusevski           0
# Fabio Quagliarella         2
# Fabrizio Caligara          0
# Federico Bernardeschi      2
# Federico Chiesa            0
# Federico Peluso            0
# Gianluca Frabotta          0
# Gianluigi Buffon           0
# Giorgio Chiellini          1
# Gonzalo Higuaín           17
# Hernanes                   0
# Juan Cuadrado              4
# Leonardo Bonucci           1
# Leonardo Spinazzola        0
# Marco Olivieri             0
# Mario Mandžukić           18
# Marko Pjaca                1
# Martín Cáceres             0
# ...

# %%
cl.loc[(cl['team'] == 'juventus'), ['name','goals']].groupby(['name']).sum().max()
# Out:
# goals    80
# dtype: int64

# %%
cl[cl['assists'].isnull()]
# Out:
#       Unnamed: 0              name                  season season year  \
# 0              0  Robin van Persie  Champions League 13/14       13/14
# 14            14      Tim Hoogland  Champions League 13/14       13/14
# 21            21  Dimitar Berbatov  Champions League 14/15       14/15
# 47            47       Dennis Aogo  Champions League 14/15       14/15
# 80            80      Wayne Rooney  Champions League 13/14       13/14
# ...          ...               ...                     ...         ...
# 4335        4335     Islam Slimani  Champions League 14/15       14/15
# 4362        4362           Fabinho  Champions League 14/15       14/15
# 4569        4569         Naby Sarr  Champions League 14/15       14/15
# 4571        4571        Leroy Sané  Champions League 14/15       14/15
# 5517        5517       Carlos Mané  Champions League 14/15       14/15
#
#                    team  rating  goals  bigChancesCreated  bigChancesMissed  \
# ...

# %%
matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
cl.loc[(cl['team'] == 'juventus'), ['name','goals']].groupby(['name']).sum().plot()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
cl.loc[(cl['team'] == 'juventus'), ['name','goals']].groupby(['name']).sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='name'>
